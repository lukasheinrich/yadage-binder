# %%
from yadage.steering_api import run_workflow

# %%
# %%bash
# #empty out the workdir form potential previous runs...
# rm -rf /workdir/*
# ls -lrt /workdir
# Out:
# total 0

# %%
ctx = {
    'inputdatasets':['data1.root','data2.root','data3.root']
}

# %%
run_workflow('/workdir','lhcb_talk/simple_mapreduce.yml',ctx,'from-github')

# %%
# !ls /workdir/
# Out:
# adage_stages.dot		  mapstep_0.cid       mapstep_2.pull.log
# adage_stages.pdf		  mapstep_0.pull.log  mapstep_2.run.log
# adage_workflow_instance.dot	  mapstep_0.run.log   mapstep_2.step.log
# adage_workflow_instance.pdf	  mapstep_0.step.log  outputfile.yml
# adagesnap.txt			  mapstep_1.cid       reduce_reduce.cid
# data_acquisition_single.cid	  mapstep_1.pull.log  reduce_reduce.pull.log
# data_acquisition_single.pull.log  mapstep_1.run.log   reduce_reduce.run.log
# data_acquisition_single.run.log   mapstep_1.step.log  reduce_reduce.step.log
# data_acquisition_single.step.log  mapstep_2.cid       workflow.gif

# %%
from IPython.display import HTML
import base64
imgstring = base64.b64encode(open('/workdir/workflow.gif').read())
HTML('<img alt="Embedded Image" src="data:image/png;base64,{}" />'.format(imgstring))
# Out:
# <img alt="Embedded Image" src="data:image/png;base64,..." />

# %%
from wand.image import Image as WImage
WImage(filename='/workdir/adage_stages.pdf', resolution=72)
# Out:
# <wand.image.Image: cc7e0ec 'PDF' (216x260)>

# %%
WImage(filename='/workdir/adage_workflow_instance.pdf', resolution=60)
# Out:
# <wand.image.Image: d6b1812 'PDF' (563x397)>
