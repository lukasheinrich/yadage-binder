# %%
from yadage.steering_api import run_workflow

# %%
import yaml
with open('ctx.yml','w') as ctx:
    ctx.write(yaml.safe_dump({
  'dataset_data': 'data.periodA.pool.root',
  'dataset_mcback_one': 'mc.backgroundA.poo.root',
  'dataset_mcback_two': 'mc.backgroundA.poo.root',
  'signal_par_one': 2,
  'signal_par_two': 5,
  'data_driven_cut': 0.3,
}))

# %%
# %%bash
# #empty out the workdir form potential previous runs...
# rm -rf /workdir/
# ls -lrt /workdir
# Out:
# total 0
# rm: cannot remove '/workdir/': Device or resource busy

# %%
run_workflow('/workdir','/workdir','complex_analysis/fullworkflow.yml','ctx.yml','from-github')

# %%
# %%bash
# cp /workdir/workflow.gif workflow.gif
# #copying because apparently ipython in docker and bound volumes don't play nice together?

# %% [markdown]
# ![](workflow.gif)

# %%
# !head -n20 /workdir/output.hepmc
# Out:
# head: cannot open '/workdir/output.hepmc' for reading: No such file or directory

# %%
# !pip install wand
# Out:
# Requirement already satisfied (use --upgrade to upgrade): wand in /usr/lib64/python2.7/site-packages

# %%
from wand.image import Image as WImage
WImage(filename='/workdir/adage_stages.pdf', resolution=72)
# Out:
# <wand.image.Image: 16ed6d2 'PDF' (684x332)>

# %%
from wand.image import Image as WImage
WImage(filename='/workdir/adage_workflow_instance.pdf', resolution=72)
# Out:
# <wand.image.Image: c0c7462 'PDF' (2006x620)>

# %%
# !ls /workdir/
# Out:
# acquire_signal_single.cid		hist_mc2_reduce.cid
# acquire_signal_single.pull.log		hist_mc2_reduce.pull.log
# acquire_signal_single.run.log		hist_mc2_reduce.run.log
# acquire_signal_single.step.log		hist_mc2_reduce.step.log
# adage_stages.dot			hist_mcsignal_reduce.cid
# adage_stages.pdf			hist_mcsignal_reduce.pull.log
# adage_workflow_instance.dot		hist_mcsignal_reduce.run.log
# adage_workflow_instance.pdf		hist_mcsignal_reduce.step.log
# adagesnap.txt				mc.backgroundA.poo.root.ntup.root
# back1.histos.root			mcback1_single.cid
# back2.histos.root			mcback1_single.pull.log
# data.histos.root			mcback1_single.run.log
# data_driven_back_hists_reduce.cid	mcback1_single.step.log
# data_driven_back_hists_reduce.pull.log	mcback2_single.cid
# data_driven_back_hists_reduce.run.log	mcback2_single.pull.log
# data_driven_back_hists_reduce.step.log	mcback2_single.run.log
# estimate.hist.root			mcback2_single.step.log
# fit.workspace.root			mcsignal_reduce.cid
# fit_zipped.cid				mcsignal_reduce.pull.log
# fit_zipped.pull.log			mcsignal_reduce.run.log
# fit_zipped.run.log			mcsignal_reduce.step.log
# fit_zipped.step.log			plots
# fitresults.yaml				plots_zipped.cid
# hist_data_reduce.cid			plots_zipped.pull.log
# hist_data_reduce.pull.log		plots_zipped.run.log
# hist_data_reduce.run.log		plots_zipped.step.log
# hist_data_reduce.step.log		preparedata_single.cid
# hist_estimate_zipped.cid		preparedata_single.pull.log
# hist_estimate_zipped.pull.log		preparedata_single.run.log
# hist_estimate_zipped.run.log		preparedata_single.step.log
# hist_estimate_zipped.step.log		signal.histos.root
# hist_mc1_reduce.cid			signal.input.root
# hist_mc1_reduce.pull.log		signal.ntup.root
# hist_mc1_reduce.run.log			workflow.gif
# hist_mc1_reduce.step.log
